# %%
import xarray as xr
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
FESOM_global_theta_average = xr.open_dataset("thetaoga_fesom_complete.nc", decode_times=False)

# %%
f, ax = plt.subplots(1,1, dpi=150)
ax.grid(ls=":", lw=0.33)
ax.plot(FESOM_global_theta_average.thetaoga)
